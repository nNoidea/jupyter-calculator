# %%
import math  # Basic math stuff and constants.
from sympy import *

init_printing()  # Set setting on to print everything in Latex.


def s(variable):  # faster way to define symbols.
    return symbols(variable)


pi = math.pi
